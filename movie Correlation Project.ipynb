# %%
#import libraries
import pandas as pd 
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
#matplotlib.rcParams['figure.figsize']=(12,8)
import datetime as dt

# %%
#read in the data #df as dataframe
df=pd.read_csv('/Users/yiko/Desktop/movies.csv')

# %%
#glimpse of data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#lets see if there is any missing data
for col in df.columns:
    pct_missing=np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
#df.isnull()
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#data type for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#change data type of columns 
#use dropna or fillna to replace nan/null to 0 values

#Astype is used to change data type of a series


df=df.dropna()

df['budget']=df['budget'].astype(int)
df['gross']=df['gross'].astype(int)
df['runtime']=df['runtime'].astype(int)
df['votes']=df['votes'].astype(int)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
#df['YearCorrect']=df['released'].astype(str).str[9:13]

#this didnt work since each month has different numebr of strs

#date_str=string[0:12]
#print(date_str)
#date1=dt.datetime.strptime(date_str,'%B-%d-%Y')
#df

# %%
#converting june to int date

string1='1980 June 13'
df.released=dt.datetime.strptime(string1,'%Y %B %d')     
#print(df.released)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year   released  score    votes         director  \
# ...

# %%
#Create correct year column
df['YearCorrect']=df['released'].astype(str).str[:4]
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year   released  score    votes         director  \
# ...

# %%
#to get rid of time
#currentDateTime = dt.datetime.now()
#currentDateWithoutTime = currentDateTime.date()
#print(currentDateTime)
#print(currentDateWithoutTime)

# %%
#create collect year column
#df['yearcorrect']=df['released'].astype(str).str[:4]
#df

# %%
#Drop Year and Released columns
#df.drop([5,6], axis=0, inplace=True)


df.drop(['year','released'],axis=1, inplace=True)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       score    votes         director                   writer  \
# ...

# %%
#DataFrame.sort_values(by, axis=0, ascending=True, inplace=False, kind=’quicksort’, na_position=’last’)
#by: Single/List of column names to sort Data Frame by. 
#axis: 0 or ‘index’ for rows and 1 or ‘columns’ for Column. 
#ascending: Boolean value which sorts Data frame in ascending order if True. 
#inplace: Boolean value. Makes the changes in passed data frame itself if True. 
#kind: String which can have three inputs(‘quicksort’, ‘mergesort’ or ‘heapsort’) of algorithm used to sort data frame. 
#na_position: Takes two string input ‘last’ or ‘first’ to set position of Null values. Default is ‘last’.

df.sort_values('gross',axis=0,inplace=True,ascending=False)#kind='quicksort',na_positon='last')
df
# Out:
#                                             name     rating   genre  score  \
# 5445                                      Avatar      PG-13  Action    7.8
# 7445                           Avengers: Endgame      PG-13  Action    8.4
# 3045                                     Titanic      PG-13   Drama    7.8
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action    7.8
# 7244                      Avengers: Infinity War      PG-13  Action    8.4
# ...                                          ...        ...     ...    ...
# 5640                                 Tanner Hall          R   Drama    5.8
# 2434                  Philadelphia Experiment II      PG-13  Action    4.5
# 3681                                Ginger Snaps  Not Rated   Drama    6.8
# 272                                     Parasite          R  Horror    3.9
# 3203                                  Trojan War      PG-13  Comedy    5.7
#
#         votes             director                   writer  \
# ...

# %%
#df.sort_values('budget',axis=0, inplace=True, ascending=False)
#df

# %%
#pd.set_option('display.max_rows',None)

# %%
#Drop if there are any duplicates
df['company'].drop_duplicates().sort_values(ascending=False)
df
# Out:
#                                             name     rating   genre  score  \
# 5445                                      Avatar      PG-13  Action    7.8
# 7445                           Avengers: Endgame      PG-13  Action    8.4
# 3045                                     Titanic      PG-13   Drama    7.8
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action    7.8
# 7244                      Avengers: Infinity War      PG-13  Action    8.4
# ...                                          ...        ...     ...    ...
# 5640                                 Tanner Hall          R   Drama    5.8
# 2434                  Philadelphia Experiment II      PG-13  Action    4.5
# 3681                                Ginger Snaps  Not Rated   Drama    6.8
# 272                                     Parasite          R  Horror    3.9
# 3203                                  Trojan War      PG-13  Comedy    5.7
#
#         votes             director                   writer  \
# ...

# %%
#drop entire duplicates
df.drop_duplicates()
# Out:
#                                             name     rating   genre  score  \
# 5445                                      Avatar      PG-13  Action    7.8
# 7445                           Avengers: Endgame      PG-13  Action    8.4
# 3045                                     Titanic      PG-13   Drama    7.8
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action    7.8
# 7244                      Avengers: Infinity War      PG-13  Action    8.4
# ...                                          ...        ...     ...    ...
# 5640                                 Tanner Hall          R   Drama    5.8
# 2434                  Philadelphia Experiment II      PG-13  Action    4.5
# 3681                                Ginger Snaps  Not Rated   Drama    6.8
# 272                                     Parasite          R  Horror    3.9
# 3203                                  Trojan War      PG-13  Comedy    5.7
#
#         votes             director                   writer  \
# ...

# %%
#Scatter plot with budget vs gross

plt.scatter(df.budget,df.gross)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for flim')
plt.legend(['budget for Flims'])
plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  score  \
# 5445                                      Avatar  PG-13  Action    7.8
# 7445                           Avengers: Endgame  PG-13  Action    8.4
# 3045                                     Titanic  PG-13   Drama    7.8
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action    7.8
# 7244                      Avengers: Infinity War  PG-13  Action    8.4
#
#         votes       director              writer               star  \
# 5445  1100000  James Cameron       James Cameron    Sam Worthington
# 7445   903000  Anthony Russo  Christopher Markus  Robert Downey Jr.
# 3045  1100000  James Cameron       James Cameron  Leonardo DiCaprio
# 6663   876000    J.J. Abrams     Lawrence Kasdan       Daisy Ridley
# 7244   897000  Anthony Russo  Christopher Markus  Robert Downey Jr.
#
#             country     budget       gross                company  runtime  \
# ...

# %%
#Plot budget vs gross using seaborn

sns.regplot('budget','gross',data=df,scatter_kws={'color':'red'},line_kws={'color':'blue'})
# Out:
# /Users/yiko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#lets start looking at correlation
#only working on the numerical corr()

df.corr(method='pearson') #different types of corr() pearson,kendall,spearman
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
#High correlation between budget and gross

# %%
correlation_matrix=df.corr(method='pearson')
sns.heatmap(correlation_matrix,annot=True) #annotation shows numbers
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
#look at Company
df.head()
# Out:
#                                             name rating   genre  score  \
# 5445                                      Avatar  PG-13  Action    7.8
# 7445                           Avengers: Endgame  PG-13  Action    8.4
# 3045                                     Titanic  PG-13   Drama    7.8
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action    7.8
# 7244                      Avengers: Infinity War  PG-13  Action    8.4
#
#         votes       director              writer               star  \
# 5445  1100000  James Cameron       James Cameron    Sam Worthington
# 7445   903000  Anthony Russo  Christopher Markus  Robert Downey Jr.
# 3045  1100000  James Cameron       James Cameron  Leonardo DiCaprio
# 6663   876000    J.J. Abrams     Lawrence Kasdan       Daisy Ridley
# 7244   897000  Anthony Russo  Christopher Markus  Robert Downey Jr.
#
#             country     budget       gross                company  runtime  \
# ...

# %%
df_numerized=df

for col_name in df.columns:
    if(df_numerized[col_name].dtype=='object'):
        df_numerized[col_name]=df[col_name].astype('category')
        df_numerized[col_name]=df[col_name].cat.codes
df_numerized
# Out:
#       name  rating  genre  score    votes  director  writer  star  country  \
# 5445   386       5      0    7.8  1100000       785    1263  1534       47
# 7445   388       5      0    8.4   903000       105     513  1470       47
# 3045  4909       5      6    7.8  1100000       785    1263  1073       47
# 6663  3643       5      0    7.8   876000       768    1806   356       47
# 7244   389       5      0    8.4   897000       105     513  1470       47
# ...    ...     ...    ...    ...      ...       ...     ...   ...      ...
# 5640  3794       6      6    5.8     3500       585    2924  1498       47
# 2434  2969       5      0    4.5     1900      1805    3102   186       47
# 3681  1595       3      6    6.8    43000       952    1683   527        6
# 272   2909       6      9    3.9     2300       261      55  1473       47
# 3203  4966       5      4    5.7     5800       651     161  1811       47
#
#          budget       gross  company  runtime  YearCorrect
# ...

# %%
df
# Out:
#                                             name     rating   genre  score  \
# 5445                                      Avatar      PG-13  Action    7.8
# 7445                           Avengers: Endgame      PG-13  Action    8.4
# 3045                                     Titanic      PG-13   Drama    7.8
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action    7.8
# 7244                      Avengers: Infinity War      PG-13  Action    8.4
# ...                                          ...        ...     ...    ...
# 5640                                 Tanner Hall          R   Drama    5.8
# 2434                  Philadelphia Experiment II      PG-13  Action    4.5
# 3681                                Ginger Snaps  Not Rated   Drama    6.8
# 272                                     Parasite          R  Horror    3.9
# 3203                                  Trojan War      PG-13  Comedy    5.7
#
#         votes             director                   writer  \
# ...

# %%
correlation_matrix=df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix,annot=True) #annotation shows numbers
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre     score     votes  director  \
# name         1.000000 -0.029234  0.010996  0.014450  0.012615  0.015246
# rating      -0.029234  1.000000  0.147796  0.065983  0.006031  0.014656
# genre        0.010996  0.147796  1.000000  0.035106 -0.135990 -0.008553
# score        0.014450  0.065983  0.035106  1.000000  0.474256  0.005413
# votes        0.012615  0.006031 -0.135990  0.474256  1.000000 -0.010376
# director     0.015246  0.014656 -0.008553  0.005413 -0.010376  1.000000
# writer       0.012880 -0.003149  0.017578  0.012843 -0.005316  0.261735
# star        -0.006882  0.009196  0.003341  0.007296 -0.017638  0.036593
# country     -0.025490  0.008230 -0.009164 -0.043051  0.041551  0.011133
# budget       0.023392 -0.203946 -0.368523  0.072001  0.439675 -0.009662
# gross        0.005639 -0.181906 -0.244101  0.222556  0.614751 -0.029560
# company      0.021697 -0.092357 -0.071334  0.020656  0.118470 -0.008223
# ...

# %%
correlation_mat=df_numerized.corr()
corr_pairs=correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              score          0.014450
#              votes          0.012615
#                               ...
# YearCorrect  budget              NaN
#              gross               NaN
#              company             NaN
#              runtime             NaN
#              YearCorrect         NaN
# Length: 196, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget       genre         -0.368523
# genre        budget        -0.368523
# gross        genre         -0.244101
# genre        gross         -0.244101
# rating       budget        -0.203946
#                               ...
# YearCorrect  budget              NaN
#              gross               NaN
#              company             NaN
#              runtime             NaN
#              YearCorrect         NaN
# Length: 196, dtype: float64

# %%
high_corr=sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# gross     votes       0.614751
# votes     gross       0.614751
# gross     budget      0.740247
# budget    gross       0.740247
# name      name        1.000000
# writer    writer      1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# director  director    1.000000
# votes     votes       1.000000
# score     score       1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
#vote and bugdet have the highest correlation to gorss earnings
#company had low correlation
