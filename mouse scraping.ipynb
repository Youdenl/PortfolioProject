# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
title=[]
type_1=[]
rating=[]
price=[]
discount=[]
for i in range(1,100):
    url= (f'https://www.flipkart.com/laptop-accessories/mouse/pr?sid=6bo%2Cai3%2C2ay&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIk1vdXNlIl0sInZhbHVlVHlwZSI6Ik1VTFRJX1ZBTFVFRCJ9fX19fQ%3D%3D&otracker=clp_metro_expandable_4_4.metroExpandable.METRO_EXPANDABLE_Mouse_computer-accessories-store_IVXW3QK63QSR_wp3&fm=neo%2Fmerchandising&iid=M_44e46fa2-8bb1-439e-95ae-b1909cef0cfa_4.IVXW3QK63QSR&ppt=browse&ppn=browse&ssid=25wnhwa0w00000001657251887913&page={i}')
    r= requests.get(url)
    soup= bs(r.content,'lxml')
    lists=soup.find_all('div',class_='_1YokD2 _3Mn1Gg')
    for soup in lists[0:20]:
        title1=soup.find('a',class_='s1Q9rs').text
        title.append(title1)
        
        type2=soup.find('div',class_='_3Djpdu').text
        type_1.append(type2)
        
        rating1=soup.find('div',class_='_3LWZlK').text
        rating.append(rating1)
        
        price1=soup.find('div',class_='_30jeq3').text
        price.append(price1)
        
        discount1=soup.find('div',class_='_3Ay6Sb').text
        discount.append(discount1)
        
        print(title1,'\n','',type2,'\n','',rating1,'\n','',price1,'\n','',discount1)
# Out:
# Lenovo 130 Wireless Optical Mouse
#   2.4GHz Wireless, Black
#   4.5
#   ₹549
#   49% off
# Zoook Blade / Rechargeable, 7 Color RGB, Silent Wireles...
#   2.4GHz Wireless, Rose Gold
#   4.3
#   ₹489
#   75% off
# Logitech Pebble M350 / Silent Buttons, Bluetooth or USB...
#   2.4GHz Wireless, Bluetooth, Rose
#   4.6
#   ₹1,514
#   24% off
# HP M10 Wired Optical Mouse
#   USB 2.0, Black
#   4.4
#   ₹349
#   12% off
# TERABYTE (TB -36B) USB Wired Optical Mouse
#   USB 2.0, Black
#   4.2
#   ₹185
#   38% off
# DELL Premier Rechargeable MS7421W Wireless Optical Mous...
#   2.4GHz Wireless, Platinum Silver
#   4.5
#   ₹3,629
#   48% off
# Logitech M590 / Multi-Device Silent with 7 Customizable...
#   Grey
#   4.5
#   ₹2,795
#   6% off
# Frontech MS-0027 USB Wired Optical Mouse
#   USB 2.0, Black
#   4.4
#   ₹235
#   6% off
# LAPCARE L-70 Wired Optical Mouse
#   USB, Black
#   4.2
#   ₹199
#   33% off
# ZEBRONICS Comfort + Wired Optical Mouse
#   USB 2.0, Black
#   4.8
#   ₹194
#   35% off
# ...

# %%
#with open('mouse.csv','w',encoding='utf8',newline='')as f:
    #thewriter=writer(f)
    #header = ['Title','Type','Rating','Price','Discount']
    #thewriter.writerow(header)
    
    #for list in lists:
        #title=list.find('a',class_='s1Q9rs').text
        #type1=list.find('div',class_='_3Djpdu').text
        #rating=list.find('div',class_='_3LWZlK').text
        #price=list.find('div',class_='_30jeq3').text
        #discount=list.find('div',class_='_3Ay6Sb').text
        #info=[title,type1,rating,price,discount]
        #thewriter.writerow(info)
